# %% [markdown]
# # IAU Projekt - Fáza 4 - Aktivity na cvičení
# Peter Brenkus, Tomáš Brček
#
# Percentuálny podiel: 50/50

# %%
import os
import math
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
# Out:
# 2024-12-04 14:02:03.582919: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-04 14:02:03.591377: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-04 14:02:03.684246: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-04 14:02:03.761440: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733317323.830295    5486 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733317323.853251    5486 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-04 14:02:03.955912: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
os.environ['TF_DETERMINISTIC_OPS'] = '1'

IMAGE_SIZE = 128
BATCH_SIZE = 10

DATASET_DIR = "data/head_ct"
LABELS_FILE = "data/labels.csv"

base_path = "data/head_ct"

# %% [markdown]
# # 4.1 EDA and data preprocessing

# %% [markdown]
# ## A
#
# EDA a data preprocessing pre Vami vybrané charakteristiky z datasetu

# %%
labels = pd.read_csv("data/labels.csv", index_col="id")

# %%
files = sorted(os.listdir(DATASET_DIR))
normal_imgs = [fn for fn in files if labels.loc[int(fn.split('.')[0]), ' hemorrhage'] == 0]
hemorrhage_imgs = [fn for fn in files if labels.loc[int(fn.split('.')[0]), ' hemorrhage'] == 1]
print(f'Num. normal: {len(normal_imgs)}, num. hemorrhage: {len(hemorrhage_imgs)}')
# Out:
# Num. normal: 100, num. hemorrhage: 100

# %% [markdown]
# Môžeme vidieť, že medzi obrázkami máme 100 takých, ktoré sú normálne a 100 takých, na ktorých je krvácanie. Tieto triedy sme si rozdelili do 2 polí.

# %% [markdown]
# ### Zobrazenie vzorky

# %%
normal_selection = np.random.choice(normal_imgs, 5, replace = False)
hemorrhage_selection = np.random.choice(hemorrhage_imgs, 5, replace = False)

# %%
fig = plt.figure(figsize=(12, 12)) 
for i in range(10):
    if i < 5:
        fp = f'data/head_ct/{normal_selection[i]}'
        label = 'NORMAL'
    else:
        fp = f'data/head_ct/{hemorrhage_selection[i-6]}'
        label = 'HEMORRHAGE'
    ax = fig.add_subplot(5, 5, i+1)
    
    fn = image.load_img(fp, color_mode='grayscale')
    plt.imshow(fn, cmap='Greys_r')
    plt.title(label)
    plt.axis('off')
plt.show()

# %% [markdown]
# Vybrali sme vzorku 5 obrázkov z každej triedy, ktoré sme si vykreslili pre lepšiu predstavu.

# %% [markdown]
# ### Zobrazenie priemerného príkladu

# %%
def convert_images_to_matrix(directory, filenames, size=(IMAGE_SIZE, IMAGE_SIZE)):
    full_matrix = None
    for filename in filenames:
        file_path = os.path.join(directory, filename)
        loaded_image = image.load_img(file_path, target_size=size, color_mode='grayscale')
        image_array = image.img_to_array(loaded_image).ravel()[np.newaxis, :]
        if full_matrix is None:
            full_matrix = image_array
        else:
            full_matrix = np.vstack((full_matrix, image_array))
    return full_matrix

normal = convert_images_to_matrix('data/head_ct/', normal_imgs)
hemorrhage = convert_images_to_matrix('data/head_ct/', hemorrhage_imgs)

# %%
def find_mean_img(full_mat, title, size=(IMAGE_SIZE, IMAGE_SIZE)):
    mean_img = np.mean(full_mat, axis = 0)
    mean_img = mean_img.reshape(size)
    plt.imshow(mean_img, vmin=0, vmax=255, cmap='Greys_r')
    plt.title(f'AVG {title} case')
    plt.axis('off')
    plt.show()
    return mean_img

norm_mean_img = find_mean_img(normal, 'normal')
hemorrhage_mean_img = find_mean_img(hemorrhage, 'hemorrhage')

# %% [markdown]
# Na obrázkoch vyššie môžeme vidieť priemerné prípady pre normálne snímky, a pre snímky, ktoré obsahujú krvácanie.

# %% [markdown]
# ### Príprava datasetu

# %%
SEED =42
tf.random.set_seed(SEED)
np.random.seed(SEED)

def load_image_and_label(image_name, label):
    img_path = tf.strings.join([DATASET_DIR, image_name], separator="/")
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=1)
    img = tf.image.resize(img, [IMAGE_SIZE, IMAGE_SIZE])
    return img, label

# %%
normal_labels = [0] * len(normal_imgs)
hemorrhage_labels = [1] * len(hemorrhage_imgs)

# %%
normal_dataset = tf.data.Dataset.from_tensor_slices((normal_imgs, normal_labels)).map(load_image_and_label)
hemorrhage_dataset = tf.data.Dataset.from_tensor_slices((hemorrhage_imgs, hemorrhage_labels)).map(load_image_and_label)
# Out:
# 2024-12-04 14:02:08.368149: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
full_dataset = normal_dataset.concatenate(hemorrhage_dataset)
full_dataset = full_dataset.shuffle(buffer_size=len(full_dataset), seed=SEED, reshuffle_each_iteration=False)

# %% [markdown]
# #### Rozdelenie na trénovacie a testovacie dáta

# %%
train_size = int(0.7 * len(full_dataset))
val_size = int(0.2 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

train_dataset = full_dataset.take(train_size).batch(BATCH_SIZE, drop_remainder=True)
val_dataset = full_dataset.skip(train_size).take(val_size).batch(BATCH_SIZE, drop_remainder=True)
test_dataset = full_dataset.skip(train_size).skip(val_size).batch(BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# ## B
#
# Zdôvodnite výber ML/DL metód vzhľadom na Vami vybraný dataset pre 4.2

# %% [markdown]
# # 4.2 Modeling and evaluation

# %% [markdown]
# ## A
#
# Modeluje Vami tie vybrané charakteristiky pomocou vhodných ML/DL metód. Výsledok modelovania je najlepší model.

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
from sklearn.metrics import accuracy_score

def create_model(input_shape):
    inputs = x = tf.keras.Input(shape=input_shape, name="inputs")

    x = layers.Rescaling(1./255)(x)

    x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.35)(x)
    
    x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.35)(x)

    x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.35)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.6)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)
    
    return Model(inputs=inputs, outputs=outputs)

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 1)
model = create_model(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=30,  # Zvýšený počet epoch
    verbose=1
)
# Out:
# Epoch 1/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - accuracy: 0.5635 - loss: 0.8450 - val_accuracy: 0.4500 - val_loss: 0.6923
# Epoch 2/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.5105 - loss: 0.6849 - val_accuracy: 0.4750 - val_loss: 0.6874
# Epoch 3/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.5551 - loss: 0.6893 - val_accuracy: 0.5000 - val_loss: 0.6832
# Epoch 4/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - accuracy: 0.5872 - loss: 0.6568 - val_accuracy: 0.8000 - val_loss: 0.6591
# Epoch 5/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.6744 - loss: 0.6309 - val_accuracy: 0.7250 - val_loss: 0.5853
# Epoch 6/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.6190 - loss: 0.6347 - val_accuracy: 0.7500 - val_loss: 0.6043
# Epoch 7/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.6392 - loss: 0.5888 - val_accuracy: 0.8500 - val_loss: 0.5551
# Epoch 8/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.7012 - loss: 0.5147 - val_accuracy: 0.8000 - val_loss: 0.5260
# Epoch 9/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - accuracy: 0.7658 - loss: 0.4997 - val_accuracy: 0.7750 - val_loss: 0.5314
# Epoch 10/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.6717 - loss: 0.5367 - val_accuracy: 0.8750 - val_loss: 0.4708
# Epoch 11/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 0.8029 - loss: 0.4506 - val_accuracy: 0.7250 - val_loss: 0.5158
# Epoch 12/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.7172 - loss: 0.5798 - val_accuracy: 0.8750 - val_loss: 0.5152
# Epoch 13/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.8574 - loss: 0.4958 - val_accuracy: 0.8000 - val_loss: 0.4056
# Epoch 14/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - accuracy: 0.7916 - loss: 0.4555 - val_accuracy: 0.9000 - val_loss: 0.4450
# Epoch 15/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.8046 - loss: 0.4449 - val_accuracy: 0.8750 - val_loss: 0.3889
# Epoch 16/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.8103 - loss: 0.4179 - val_accuracy: 0.8750 - val_loss: 0.3600
# Epoch 17/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.8260 - loss: 0.4326 - val_accuracy: 0.7750 - val_loss: 0.4324
# Epoch 18/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - accuracy: 0.7822 - loss: 0.4415 - val_accuracy: 0.9250 - val_loss: 0.3742
# Epoch 19/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.8235 - loss: 0.4174 - val_accuracy: 0.9000 - val_loss: 0.2866
# Epoch 20/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 260ms/step - accuracy: 0.8762 - loss: 0.3277 - val_accuracy: 0.9000 - val_loss: 0.2947
# Epoch 21/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - accuracy: 0.8283 - loss: 0.3678 - val_accuracy: 0.8250 - val_loss: 0.4065
# Epoch 22/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.7884 - loss: 0.4185 - val_accuracy: 0.9000 - val_loss: 0.2907
# Epoch 23/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.8817 - loss: 0.3216 - val_accuracy: 0.9500 - val_loss: 0.2523
# Epoch 24/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 0.8631 - loss: 0.3088 - val_accuracy: 0.9000 - val_loss: 0.2201
# Epoch 25/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - accuracy: 0.9112 - loss: 0.2751 - val_accuracy: 0.9000 - val_loss: 0.2777
# Epoch 26/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.8494 - loss: 0.2768 - val_accuracy: 0.9000 - val_loss: 0.2856
# Epoch 27/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.8705 - loss: 0.2862 - val_accuracy: 0.9000 - val_loss: 0.2492
# Epoch 28/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.9332 - loss: 0.2165 - val_accuracy: 0.9250 - val_loss: 0.2113
# Epoch 29/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.8951 - loss: 0.2131 - val_accuracy: 0.9250 - val_loss: 0.2312
# Epoch 30/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 259ms/step - accuracy: 0.9098 - loss: 0.2215 - val_accuracy: 0.9250 - val_loss: 0.2411

# %%
test_loss, test_accuracy = model.evaluate(test_dataset, verbose=1)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9333 - loss: 0.3009
# Test Loss: 0.3628, Test Accuracy: 0.9000

# %%
train_loss, train_accuracy = model.evaluate(train_dataset, verbose=1)
print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9814 - loss: 0.1482
# Train Loss: 0.1544, Train Accuracy: 0.9714

# %% [markdown]
# ## B
#
# Zhodnotíte Váš prístup a získaný výsledok
